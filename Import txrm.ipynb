# %%
import xrmreader

# %%
projection_data = r'c:\Users\Admin\OneDrive\Documents\Drexel\MEM 697\DataVisualization\Hadrasaur Tooth_080224/Hadrasaur Tooth_080224_2024-08-02_164845/tomo-A'

metadata = xrmreader.read_metadata(projection_data)
print(metadata)
# Out:
# Unknown file extension
# No such file or directory: %s c:\Users\Admin\OneDrive\Documents\Drexel\MEM 697\DataVisualization\Hadrasaur Tooth_080224\Hadrasaur Tooth_080224_2024-08-02_164845\tomo-A
# False
